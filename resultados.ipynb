# %%
import pandas as pd

# %%
resultados = pd.DataFrame({
    'Modelo': [
        'SVC',
        'LogisticRegression',
        'GaussianNB',
        'DecisionTreeClassifier'
    ],
    'Accuracy': [
        0.8706060606060606,
        0.8718181818181818,
        0.6427272727272727,
        0.7163636363636363
    ],
    'F1 positive': [
        0.87400413,
        0.87488909,
        0.6366718,
        0.71807229
    ],
    'F1 negative': [
        0.86701962,
        0.86859273,
        0.6485842,
        0.71463415
    ]
})

resultados
# Out:
#                    Modelo  Accuracy  F1 positive  F1 negative
# 0                     SVC  0.870606     0.874004     0.867020
# 1      LogisticRegression  0.871818     0.874889     0.868593
# 2              GaussianNB  0.642727     0.636672     0.648584
# 3  DecisionTreeClassifier  0.716364     0.718072     0.714634
